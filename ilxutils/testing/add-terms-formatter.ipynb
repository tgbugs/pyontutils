# %%
import json
import pandas as pd
from interlex_sql import interlex_sql 
from args_reader import read_args
from scicrunch_client_fast import scicrunch
from collections import defaultdict

# %%
args = read_args(keys='../keys.txt', production='-p')
sql = interlex_sql(engine_key=args['engine_key'])
sci = scicrunch(key='api_key', base_path=args['base_path'])

# %%
labels_to_ids = sql.get_labels_to_ids_dict()
#labels_to_ids = json.load(open('../dump/labels_to_ids_dict_complete_interlex_sql.json', 'r'))

# %%
for i, d in df.iterrows():
    if not labels_to_ids.get(' '.join(str(d.title).lower().strip().split())):
        print(str(d.title).lower().strip())
# Out:
# post‐injury surgical procedures
# post‐injury conditions
# post‐injury subject housing
# bbb right  hindpaw subscore
# bbb left  hindpaw subscore

# %%
for label in list(labels_to_ids):
    if 'injury surgical' in label:
        print(label)
# Out:
# preinjury surgical procedures
# post-injury surgical procedures

# %%
labels_to_ilx = sql.get_labels_to_ilx_dict()

# %%
inputfile = '../../OCD-CDEs/ODC-CDEs.xlsx'
df = pd.read_excel(inputfile, sheetname='Overall rough MasterStruct')
#df = df.fillna()
#raw_data = json.load(open(inputfile, 'r'))

# %%
df
# Out:
#                   ODC_Domain                 ODC_SubDomain ODC_Assessment  \
# 0   INVESTIGATOR INFORMATION      INVESTIGATOR INFORMATION            NaN
# 1   INVESTIGATOR INFORMATION      INVESTIGATOR INFORMATION            NaN
# 2   INVESTIGATOR INFORMATION      INVESTIGATOR INFORMATION            NaN
# 3   EXPERIMENTAL INFORMATION                    STUDY NAME            NaN
# 4   EXPERIMENTAL INFORMATION        Animal Characteristics            NaN
# 5   EXPERIMENTAL INFORMATION        Animal Characteristics            NaN
# 6   EXPERIMENTAL INFORMATION        Animal Characteristics            NaN
# 7   EXPERIMENTAL INFORMATION        Animal Characteristics            NaN
# 8   EXPERIMENTAL INFORMATION        Animal Characteristics            NaN
# 9   EXPERIMENTAL INFORMATION        Animal Characteristics            NaN
# 10  EXPERIMENTAL INFORMATION        Animal Characteristics            NaN
# 11  EXPERIMENTAL INFORMATION        Animal Characteristics            NaN
# 12  EXPERIMENTAL INFORMATION        Animal Characteristics            NaN
# 13  EXPERIMENTAL INFORMATION                Animal History     Pre-injury
# 14  EXPERIMENTAL INFORMATION                Animal History     Pre-injury
# 15  EXPERIMENTAL INFORMATION                Animal History     Pre-injury
# 16  EXPERIMENTAL INFORMATION                Animal History            NaN
# 17  EXPERIMENTAL INFORMATION                Animal History            NaN
# 18  EXPERIMENTAL INFORMATION                Animal History     Anesthesia
# 19  EXPERIMENTAL INFORMATION                Animal History     Anesthesia
# 20  EXPERIMENTAL INFORMATION                Animal History     Anesthesia
# 21  EXPERIMENTAL INFORMATION                Animal History            NaN
# 22  EXPERIMENTAL INFORMATION                Animal History    Post-injury
# 23  EXPERIMENTAL INFORMATION                Animal History    Post-injury
# 24  EXPERIMENTAL INFORMATION                Animal History    Post-injury
# 25  EXPERIMENTAL INFORMATION                Animal History      Treatment
# 26  EXPERIMENTAL INFORMATION                Animal History      Treatment
# 27  EXPERIMENTAL INFORMATION                Animal History      Treatment
# 28  EXPERIMENTAL INFORMATION                Animal History      Treatment
# 29  EXPERIMENTAL INFORMATION                Animal History      Treatment
# ..                       ...                           ...            ...
# 32  EXPERIMENTAL INFORMATION                Animal History            NaN
# 33  EXPERIMENTAL INFORMATION                Animal History            NaN
# 34  EXPERIMENTAL INFORMATION                Animal History            NaN
# 35  EXPERIMENTAL INFORMATION                Animal History            NaN
# 36  EXPERIMENTAL INFORMATION  Injury Model Characteristics            NaN
# 37  EXPERIMENTAL INFORMATION  Injury Model Characteristics            NaN
# 38  EXPERIMENTAL INFORMATION  Injury Model Characteristics            NaN
# 39  EXPERIMENTAL INFORMATION  Injury Model Characteristics            NaN
# 40  EXPERIMENTAL INFORMATION  Injury Model Characteristics            NaN
# 41  EXPERIMENTAL INFORMATION  Injury Model Characteristics            NaN
# 42  EXPERIMENTAL INFORMATION  Injury Model Characteristics            NaN
# 43  EXPERIMENTAL INFORMATION  Injury Model Characteristics            NaN
# 44  EXPERIMENTAL INFORMATION  Injury Model Characteristics            NaN
# 45  EXPERIMENTAL INFORMATION  Injury Model Characteristics            NaN
# 46  EXPERIMENTAL INFORMATION        Assessments & Outcomes            NaN
# 47  EXPERIMENTAL INFORMATION        Assessments & Outcomes            NaN
# 48  EXPERIMENTAL INFORMATION        Assessments & Outcomes            NaN
# 49  EXPERIMENTAL INFORMATION        Assessments & Outcomes            NaN
# 50  EXPERIMENTAL INFORMATION        Assessments & Outcomes            BBB
# 51  EXPERIMENTAL INFORMATION        Assessments & Outcomes            BBB
# 52  EXPERIMENTAL INFORMATION        Assessments & Outcomes            BBB
# 53  EXPERIMENTAL INFORMATION        Assessments & Outcomes            BBB
# 54  EXPERIMENTAL INFORMATION        Assessments & Outcomes            BBB
# 55  EXPERIMENTAL INFORMATION        Assessments & Outcomes            BBB
# 56  EXPERIMENTAL INFORMATION        Assessments & Outcomes            BBB
# 57  EXPERIMENTAL INFORMATION        Assessments & Outcomes            BBB
# 58  EXPERIMENTAL INFORMATION        Assessments & Outcomes            BBB
# 59  EXPERIMENTAL INFORMATION        Assessments & Outcomes            BBB
# 60  EXPERIMENTAL INFORMATION        Assessments & Outcomes            BBB
# 61  EXPERIMENTAL INFORMATION        Assessments & Outcomes            BBB
#
#                                      title         ODC_VariableName  \
# 0                             Investigator                      NaN
# 1                               Laboratory                      NaN
# 2              Institution or organization                      NaN
# 3   Baseline assessments and date (timing)                      NaN
# 4                                Animal ID                 AnimalID
# 5                                  Species                  Species
# 6                               Birth date                BirthDate
# 7                                Age value                   AgeVal
# 8                                Age group                 AgeGroup
# 9                                      Sex     SexSubjectGenotypTyp
# 10                           Animal vendor             AnimalVendor
# 11            Strain/genetic modifications            StrainGeneMod
# 12                      Weight measurement                 WgtMeasr
# 13              Pre-injury subject housing            PreInjHousing
# 14                    Preinjury conditions            PreinjuryCond
# 15           Preinjury surgical procedures        PreInjurySurgProc
# 16                 Injury group assignment           InjuryGpAssign
# 17                    Injury date and time              InjDateTime
# 18                         Anesthetic type           AnestheticType
# 19                        Anesthetic route          AnestheticRoute
# 20                     Anesthesia duration            AnesthesiaDur
# 21                          Analgesia type            AnalgesiaType
# 22         Post‐injury surgical procedures       PostInjurySurgProc
# 23                  Post‐injury conditions           PostInjuryCond
# 24             Post‐injury subject housing           PostInjHousing
# 25              Treatment group assignment            TreatGpAssign
# 26                         Treatment onset             TreatmtOnset
# 27     Unit of measure for treatment onset  UnitMeasureTreatmtOnset
# 28                    Drug treatment route         DrugTreatmtRoute
# 29               Treatment or therapy type       TreatmtTherapyType
# ..                                     ...                      ...
# 32                           Survival time             SurvivalTime
# 33       Unit of measure for survival time         UnitMeasSurvTime
# 34                Euthanasia date and time       EuthanasiaDateTime
# 35                      Type of euthanasia           EuthanasiaType
# 36                            Injury model                 InjModel
# 37                     Device manufacturer              DeviceManuf
# 38          Device manufacturer other text           DeviceManufOTH
# 39             Animal stabilization method   AnimalStabilizationMtd
# 40         Impact location side or midline            ImpactLocSide
# 41          Spinal region that is impacted      ImpactSpinallRegion
# 42                  Impactor depth setting     ImpactorDepthSetting
# 43                     Impactor dwell time        ImpactorDwellTime
# 44                       Impactor velocity              ImpactorVel
# 45                        Surface material             SurfMaterial
# 46                         Injury severity              InjSeverity
# 47                  Spinal level of injury              SpinalLevel
# 48                Assessment date and time         AssessmtDateTime
# 49           Acute neurological assessment       AcuteNeuroAssessmt
# 50                        BBB left hindpaw                 BBB_Left
# 51                       BBB right hindpaw                BBB_Right
# 52                             BBB average                  BBB_AVG
# 53              BBB right hindpaw rotation           BBB_RHRotation
# 54               BBB left hindpaw rotation           BBB_LHRotation
# 55         BBB right hindpaw toe clearance       BBB_RHToeClearance
# 56          BBB left hindpaw toe clearance       BBB_LHToeClearance
# 57             BBB right  hindpaw subscore           BBB_RHSubscore
# 58              BBB left  hindpaw subscore           BBB_LHSubscore
# 59                      BBB trunk subscore        BBB_TrunkSubscore
# 60                       BBB tail subscore         BBB_TailSubscore
# 61                      BBB total subscore        BBB_TotalSubScore
#
#                                            definition
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                               Animal identification
# 5                 Species of the animal being studied
# 6   Date (and time, if applicable and known) the s...
# 7                           Age at the time of injury
# 8   Value for subject's age, calculated as elapsed...
# 9   The difference between male and female, based ...
# 10                                      Animal vendor
# 11  Strain of species, including genetic modification
# 12    Measurement of subject's weight prior to injury
# 13        Individual or group housing prior to injury
# 14  List of preinjury conditions that may have bee...
# 15                Surgical procedures prior to injury
# 16                             Injury goup assignment
# 17  Date (and time, if applicable and known) of in...
# 18               Anesthesia given prior to the injury
# 19               The way the anesthesia was delivered
# 20        Length of time that animal was anesthetized
# 21  Type of analgesia delivered before, during or ...
# 22                    Surgical procedures post‐injury
# 23  List of postinjury conditions that may have be...
# 24           Individual or group housing after injury
# 25                         Treatment group assignment
# 26                          Timing relative to injury
# 27                Unit of measure for treatment onset
# 28    Route of administration of the drug or biologic
# 29  Includes pharmacological and non‐pharmacologic...
# ..                                                ...
# 32  Length of time between injury and euthanasia o...
# 33                  Unit of measure for survival time
# 34  Date (and time, if applicable and known) of eu...
# 35                               Method of euthanasia
# 36  Machine or device or procedure that provides l...
# 37                                Device manufacturer
# 38  Free text related to DeviceManuf, specifying o...
# 39  How the animal or animal's head is positioned ...
# 40  General location of impact in terms of side or...
# 41  Gross anatomical spinal locations that sustain...
# 42             Impactor depth from zero point at dura
# 43  Length of time impactor remains in the down po...
# 44                             Impactor peak velocity
# 45  Material properties of surface on which the an...
# 46  Broad classification of injury severity based ...
# 47  The segemental level of injury in the spinal c...
# 48                           Assessment date and time
# 49    Assessment of reflexes shortly after the injury
# 50  Basso, Beattie, Bresnahan (BBB) Locomotor Rati...
# 51  Basso, Beattie, Bresnahan (BBB) Locomotor Rati...
# 52  Basso, Beattie, Bresnahan (BBB) Locomotor Rati...
# 53  Basso, Beattie, Bresnahan (BBB) Locomotor Rati...
# 54  Basso, Beattie, Bresnahan (BBB) Locomotor Rati...
# 55  Basso, Beattie, Bresnahan (BBB) Locomotor Rati...
# 56  Basso, Beattie, Bresnahan (BBB) Locomotor Rati...
# 57  Basso, Beattie, Bresnahan (BBB) Locomotor Rati...
# 58  Basso, Beattie, Bresnahan (BBB) Locomotor Rati...
# 59  Basso, Beattie, Bresnahan (BBB) Locomotor Rati...
# 60  Basso, Beattie, Bresnahan (BBB) Locomotor Rati...
# 61  Basso, Beattie, Bresnahan (BBB) Locomotor Rati...
#
# [62 rows x 6 columns]

# %%
for i, row in df.iterrows():
    label = row.title.lower().strip()
    if labels_to_ids.get(label):
        print(row.title,',',labels_to_ids.get(label),',',labels_to_ilx.get(label))
        #print(row)
# Out:
# Investigator , 5687 , ilx_0105686
# Laboratory , 12818 , ilx_0112817
# Animal ID , 12869 , ilx_0112868
# Species , 10849 , ilx_0110848
# Sex , 12867 , ilx_0112866
# Pre-injury subject housing , 15039 , ilx_0115035
# Preinjury conditions , 15038 , ilx_0115034
# Preinjury surgical procedures , 15033 , ilx_0115029
# Injury group assignment , 15040 , ilx_0115036
# Survival time , 12875 , ilx_0112874

# %%
raw_data = df.to_dict('records')

# %%
col_info = {
    'ODC_Domain':15034,
    'ODC_SubDomain': 15035,
    'ODC_Assessment': 15036,
    'ODC_VariableName': 15037,#used to be heading 304378,
}
source = {'annotation_tid':15024,'value':'ODC-SCI'}

# %%
#see if any labels already exist
#create a format 
#definition, label, synonyms, superclass_label, superclass_ilx, superclass_tid

already_added_terms = []
output_data = defaultdict(dict)
for i, d in df.iterrows():    
    
    output_data[d.title].update({
        'label':d.title,
        'type':'cde',
        'annotations':[{'value':' '.join([w.lower().capitalize() for w in str(d[k]).split()]), 'annotation_tid':v} for k, v in col_info.items() if type(d[k])==str] + [source],
        })
    if type(d.definition) != float:
        if d.definition and len(d.definition) > 0:
            output_data[d.title].update({'definition':d.definition})
            
with open('/Users/tmsincomb/Desktop/OCD-CDEs/ocd-cdes-production-ready.json', 'w') as outfile:
    json.dump(output_data, outfile, indent=4)

# %%
output_data = defaultdict(dict)
for i, d in df.iterrows():
    if d.title == 'Institution or organization':
        output_data[d.title].update({
            'label':d.title,
            'definition':' ',
            'type':'cde',
            'annotations':[{'value':' '.join([w.lower().capitalize() for w in str(d[k]).split()]), 'annotation_tid':v} for k, v in col_info.items() if type(d[k])==str] + [source],
            })
        if type(d.definition) != float:
            if d.definition and len(d.definition) > 0:
                output_data[d.title].update({'definition':d.definition})
            
with open('/Users/tmsincomb/Desktop/OCD-CDEs/ocd-cdes-production-ready.json', 'w') as outfile:
    json.dump(output_data, outfile, indent=4)

# %%
sci.getAnnotationsVIAtid([304379])
# Out:
# [========================================================================] 100%
# === Getting Annotations ===
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: {'errormsg': 'Could not complete request', 'success': False} with status code [401]
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2918: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
a = {0:0, 1:1}
for i in a[:]:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-56e8bd1fdd60> in <module>()
#       1 a = {0:0, 1:1}
# ----> 2 for i in a[:]:
#       3     print(i)
#
# TypeError: unhashable type: 'slice'

# %%
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int(x=0) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __ceil__(...)
#  |      Ceiling of an Integral returns itself.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(...)
#  |      Flooring an Integral returns itself.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(...)
#  |      default object formatter
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getnewargs__(...)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __index__(self, /)
#  |      Return self converted to an integer, if self is suitable for use as an index into a list.
#  |
#  |  __int__(self, /)
#  |      int(self)
#  |
#  |  __invert__(self, /)
#  |      ~self
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lshift__(self, value, /)
#  |      Return self<<value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mod__(self, value, /)
#  |      Return self%value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __neg__(self, /)
#  |      -self
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __pos__(self, /)
#  |      +self
#  |
#  |  __pow__(self, value, mod=None, /)
#  |      Return pow(self, value, mod).
#  |
#  |  __radd__(self, value, /)
#  |      Return value+self.
#  |
#  |  __rand__(self, value, /)
#  |      Return value&self.
#  |
#  |  __rdivmod__(self, value, /)
#  |      Return divmod(value, self).
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __rfloordiv__(self, value, /)
#  |      Return value//self.
#  |
#  |  __rlshift__(self, value, /)
#  |      Return value<<self.
#  |
#  |  __rmod__(self, value, /)
#  |      Return value%self.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __round__(...)
#  |      Rounding an Integral returns itself.
#  |      Rounding with an ndigits argument also returns an integer.
#  |
#  |  __rpow__(self, value, mod=None, /)
#  |      Return pow(value, self, mod).
#  |
#  |  __rrshift__(self, value, /)
#  |      Return value>>self.
#  |
#  |  __rshift__(self, value, /)
#  |      Return self>>value.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rtruediv__(self, value, /)
#  |      Return value/self.
#  |
#  |  __rxor__(self, value, /)
#  |      Return value^self.
#  |
#  |  __sizeof__(...)
#  |      Returns size in memory, in bytes
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __truediv__(self, value, /)
#  |      Return self/value.
#  |
#  |  __trunc__(...)
#  |      Truncating an Integral returns itself.
#  |
#  |  __xor__(self, value, /)
#  |      Return self^value.
#  |
#  |  bit_length(...)
#  |      int.bit_length() -> int
#  |
#  |      Number of bits necessary to represent self in binary.
#  |      >>> bin(37)
#  |      '0b100101'
#  |      >>> (37).bit_length()
#  |      6
#  |
#  |  conjugate(...)
#  |      Returns self, the complex conjugate of any int.
#  |
#  |  from_bytes(...) from builtins.type
#  |      int.from_bytes(bytes, byteorder, *, signed=False) -> int
#  |
#  |      Return the integer represented by the given array of bytes.
#  |
#  |      The bytes argument must be a bytes-like object (e.g. bytes or bytearray).
#  |
#  |      The byteorder argument determines the byte order used to represent the
#  |      integer.  If byteorder is 'big', the most significant byte is at the
#  |      beginning of the byte array.  If byteorder is 'little', the most
#  |      significant byte is at the end of the byte array.  To request the native
#  |      byte order of the host system, use `sys.byteorder' as the byte order value.
#  |
#  |      The signed keyword-only argument indicates whether two's complement is
#  |      used to represent the integer.
#  |
#  |  to_bytes(...)
#  |      int.to_bytes(length, byteorder, *, signed=False) -> bytes
#  |
#  |      Return an array of bytes representing an integer.
#  |
#  |      The integer is represented using length bytes.  An OverflowError is
#  |      raised if the integer is not representable with the given number of
#  |      bytes.
#  |
#  |      The byteorder argument determines the byte order used to represent the
#  |      integer.  If byteorder is 'big', the most significant byte is at the
#  |      beginning of the byte array.  If byteorder is 'little', the most
#  |      significant byte is at the end of the byte array.  To request the native
#  |      byte order of the host system, use `sys.byteorder' as the byte order value.
#  |
#  |      The signed keyword-only argument determines whether two's complement is
#  |      used to represent the integer.  If signed is False and a negative integer
#  |      is given, an OverflowError is raised.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  denominator
#  |      the denominator of a rational number in lowest terms
#  |
#  |  imag
#  |      the imaginary part of a complex number
#  |
#  |  numerator
#  |      the numerator of a rational number in lowest terms
#  |
#  |  real
#  |      the real part of a complex number
